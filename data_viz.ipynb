# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from preprocessing import data_preprocess

# %%
data = pd.read_csv('archive/atp_matches_2000.csv')
data = data_preprocess(data)
data.head()
# Out:
#    surface  draw-size  tourney_level  player0_id       player0_name  \
# 0        1          1              0      102776        Andrew Ilie
# 1        1          1              0      103602  Fernando Gonzalez
# 2        1          1              0      102205   Sebastien Lareau
# 3        1          1              0      101733      Jan Siemerink
# 4        1          1              0      101826   Alex Lopez Moron
#
#    player0_hand  player0_ht  player0_ioc  player0_age  player0_rank  ...  \
# 0             1    0.363636            2     0.357283      0.046756  ...
# 1             1    0.454545            9     0.121358      0.334924  ...
# 2             1    0.454545            9     0.521358      0.125954  ...
# 3             0    0.454545           27     0.688755      0.101145  ...
# 4             1    0.212121           16     0.654340      0.104962  ...
#
#    player1_hand  player1_ht player1_ioc  player1_age  player1_rank  \
# 0             1    0.515152          16     0.529040      0.096303
# 1             1    0.151515          34     0.345621      0.118659
# 2             1    0.515152          37     0.182817      0.087704
# 3             1    0.848485          45     0.313572      0.080825
# 4             1    0.515152           2     0.688083      0.062769
#
#    player1_rank_points  best_of  round   minutes  winner
# 0             0.068660        0      4  0.527586       1
# 1             0.054692        0      4  0.265517       0
# 2             0.074366        0      4  0.189655       1
# 3             0.079874        0      4  0.486207       0
# 4             0.106433        0      4  0.175862       1
#
# [5 rows x 23 columns]

# %%
plt.figure(figsize=(6, 8))
data.corr()['winner'].plot(kind='barh')
plt.show()

# %%
plt.figure()
sns.heatmap(data.corr(), cmap='gray')
plt.show()

# %%
data.hist(layout=(8, 5), figsize=(16,20), bins='auto')
plt.show()

# %%
sns.boxplot(data['minutes'])
# Out:
# /home/sparsh/Desktop/Deep-Learning/deep-learning/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='minutes'>
